# %%
import sys
sys.path.append('../utils')
from eda_helpers import SolarDataAnalyzer


sierraleone_analyzer = SolarDataAnalyzer('sierraleone', '../data/sierraleone-bumbuna.csv')


sierraleone_analyzer.comprehensive_analysis()
# Out:
# 🚀 Starting Comprehensive EDA for benin
# ...
# === BENIN - DATA SUMMARY ===
# Dataset shape: (525598, 19)
#
# Missing Values:
#           Missing Count  Percentage (%)
# Comments         525598           100.0
#
# Columns with >5% nulls:
#           Missing Count  Percentage (%)
# Comments         525598           100.0
#
# Numeric Columns Summary:
#                  GHI            DNI            DHI           ModA  \
# count  525598.000000  525598.000000  525598.000000  525598.000000
# mean      201.958286     116.376780     113.721006     206.643881
# std       298.495457     218.652957     158.946177     300.897195
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
# ...
